# %%
from MyUtils import *

# %%
import pandas as pd

# %%
"""
- 빈 문자열을 입력으로 locale.setlocale(locale.LC_ALL, '')을 수행하면
  현지 시간/통화에 맞게 locale이 설정됨
- 필요한 이유는, 엑셀에서 읽어온 값을 float(read_data)으로 변환하는
  코드가 있는데, 이 때 1,234와 같이 쉼표를 사용하는 수 표기법을 
  처리하지 못하는 오류가 있어서... 이를 해결하기 위해 아래의 코드를
  실행함
"""
import locale
locale.setlocale(locale.LC_ALL, '')
"""
>> locale.atof('123,456.789')
123456.789
>> locale.atof('123456.789')
123456.789
"""
# Out:
# "\n>> locale.atof('123,456.789')\n123456.789\n>> locale.atof('123456.789')\n123456.789\n"

# %%
"""
유효한 시간의 범위
- 예를 들어, 엑셀 파일에는 1/1~5/31까지 있는데, (어떤 이유로) 1월 데이터는
  필요 없을 수 도 있다.
- 여튼, 유효한 시간의 범위를 지정하고, 해당 기간의 데이터에 대해서만
  처리하는 것으로 하자
"""
entireStartDateString = '2016-01-01'
entireStartDateTime = pd.to_datetime(entireStartDateString, format='%Y-%m-%d')

entireEndDateString = '2023-12-31'
entireEndDateTime = pd.to_datetime(entireEndDateString, format='%Y-%m-%d')

# %%
# 읽기, 쓰기를 위한 파일의 경로 및 파일명 설정
# - raw data file
src_dir = '../3.1 필요한 필드만 추출한 엑셀 파일/'
src_filename = '조립_2023.xlsx'
# - 처리가 완료된 데이터를 저장할 파일
#dst_dir = '../4. 정리된 엑셀 파일/'
dst_dir = '../4.1 일단위로 작업량 계산된 엑셀 파일/'
dst_filename = '3_조립실적_전체_2023.xlsx'

# %%
# raw 파일에서, 작업량 데이터가 저장된 필드 명
srcWorkloadColNames = ['중량-총량','절단장-총량']
# raw 파일에서 작업 시작일, 종료일이 문자열로 저장된 열의 이름
srcStartDateStringColName = '중량/절단장-착수일자' 
srcEndDateStringColName = '중량/절단장-완료일자' 

# 정리된 데이터가 저장될 데이터프레임의 전체 열 이름
# - 단, 첫 열에 "date"는 필수
# - 나머지 열은 raw 파일의 작업량 데이터 필드와 1:1 매칭 되어야 함(이름은 달라도 됨)
dstCompleteColumnNames = ['date', '1.가공>중량', '1.가공>절단장']
# 최종 작업량 값이 저장될 필드(열) 이름
dstWorkloadColumnNames = dstCompleteColumnNames[1:]

# %%
"""
- 디버깅을 목적으로 추가적인 출력을 만들어낼지 여부를 결정하는 변수이고,
  총 두개 함수에서 사용함 : genEmptyDataFrame, addDailyWorkload
- 특히, addDailyWorkload 는 상당한 양의 출력 구문을 생성해 내기 때문에,
  주피터 노트북을 닫을때 clear output을 하지 않으면 다음에 다시 파일을 열때
  오류가 발생할 수 있다. 따라서 clear output 이후에 파일을 닫는것을 추천한다.
  그렇지 않은 경우, 만약 노트북이 열리지 않으면 VS Code 등으로 파일을 연 다음에
  clear output을 수행하고 다시 주피터 노트북으로 열면 된다.
"""
#DEBUG_PRINT=True
DEBUG_PRINT=False

# %% [markdown]
# 데이터 불러오기

# %%
dfExcel = readExcelFile(src_dir+src_filename, _usecols="B:E")
printDataFrameInfo(dfExcel)
# Out:
# * 데이터 프레임 크기 : 21629 rows, 4 cols
# * 필드별 데이터 유형:
# 중량-총량          object
# 절단장-총량         object
# 중량/절단장-착수일자     int64
# 중량/절단장-완료일자     int64
# dtype: object
# * 최초 5개 행 출력:
#   중량-총량 절단장-총량  중량/절단장-착수일자  중량/절단장-완료일자
# 0    대조    HAC            2            2
# 1    대조    HAC            2            2
# 2    대조    HAC            9            9
# 3    대조    HAC            9            9
# 4    대조    HAC            0            0

# %%
# 테스트 : 값이 0/null인 셀의 수 확인
print(dfExcel.isnull().sum().sum())
# Out:
# 0

# %%
# 일 단위로 정리된 데이터를 저장하기 위한 데이터프레임 만들기
dfDailyHistory = genEmptyDataFrame(dtFrom = entireStartDateTime, 
                                   dtTo = entireEndDateTime,
                                   newCols = dstCompleteColumnNames,
                                   DEBUG_PRINT = DEBUG_PRINT)

print(dfDailyHistory.tail(10))
# Out:
#             date  1.가공>중량  1.가공>절단장
# 2076  2023-12-18        0         0
# 2077  2023-12-19        0         0
# 2078  2023-12-20        0         0
# 2079  2023-12-21        0         0
# 2080  2023-12-22        0         0
# 2081  2023-12-25        0         0
# 2082  2023-12-26        0         0
# 2083  2023-12-27        0         0
# 2084  2023-12-28        0         0
# 2085  2023-12-29        0         0

# %%
processedRows = 0 # 디버깅용 : 오류 없이 처리된 행 수
nRows =len(dfExcel) # raw 파일에서, 전체 데이터 수

#for row in range(TEST_CASE):
for row in range(nRows):
    if DEBUG_PRINT:
        print("Now processing row #%d"%row)

    # 1. raw 데이터 엑셀에서 데이터 획득 (사실은 엑셀을 저장한 데이터프레임에서 획득함)
    # 1.1 작업 시작일 정보 획득 
    startDateString = dfExcel[srcStartDateStringColName][row] # string
    if (type(startDateString) is not str) or (len(startDateString) != 10):
        print("잘못된 착수일자 : ", startDateString, end=' ... ')
        print("(skip 합니다)")
        continue
    dtStartDate = pd.to_datetime(startDateString, format='%Y-%m-%d')
    
    # 1.2. 작업 종료일 정보 획득
    endDateString = dfExcel[srcEndDateStringColName][row] # string
    if (type(endDateString) is not str) or (len(endDateString) != 10):
        print("잘못된 완료일자 : ", endDateString, end=' ... ')
        print("(skip 합니다)")
        continue
    dtEndDate = pd.to_datetime(endDateString, format='%Y-%m-%d')

    # 1.3. 작업 시작/종료일 관련, 오류 처리
    if dtStartDate > dtEndDate:
        print("잘못된 시작/종료 날짜 : From %s to %s (시작/종료 날짜 뒤바꿉니다)"%(startDateString,endDateString))
        startDateString, endDateString = endDateString, startDateString
        dtStartDate, dtEndDate = dtEndDate, dtStartDate
    if dtEndDate < entireStartDateTime:
        print("작업 종료일자가 유효 범위 밖에 있습니다 (skip 합니다)")
        continue
    if dtStartDate > entireEndDateTime:
        print("작업 시작일자가 유효 범위 밖에 있습니다 (skip 합니다)")
        continue
        
    # 2. 기간내에 근무일 수를 계산 (한국 명절연휴 등은 고려되지 않을 듯...)
    # 전체 작업 기간 중에 유효하지 않은 기간이 포함되어 있더라도(예: 작년말 등)
    # 일단은 전체 작업 기간에 포함해서 1/N을 수행한다.
    # 다만, 최종 데이터프레임에 저장할때는, 유효한 작업기간에 대해서만 저장함
    workingDays = getWorkingDaysFromDateTime(dtStartDate, dtEndDate)
    
    # 3. raw 파일에서 작업량 데이터 읽어오기
    workloadTotal = []
    
    for colName in srcWorkloadColNames:
        try:
            load = float(dfExcel[colName][row])  # 용접장(m) 총량
        except ValueError:
            load = locale.atof(dfExcel[colName][row])
        finally:
            # 예외 발생하든, 그렇지 않든 무조건 실행되는 영역
            # 소수점 두 번째 자리에서 반올림하기
            load = round(load, 2)
        workloadTotal.append(load)
    
    assert len(srcWorkloadColNames) == len(workloadTotal)
    if DEBUG_PRINT:
        print('start: %s, end: %s'%(startDateString, endDateString), end =", ")
        print('for workload: ', workloadTotal, end=", ")
        print('for working day: ', workingDays)

    # 최종 값이 저장될 데이터프레임에서의 필드(열) 이름 : dstWorkloadColumnNames
    assert len(dstWorkloadColumnNames) == len(srcWorkloadColNames)
    
    for workloadItemIndex in range(len(workloadTotal)):
        workload = workloadTotal[workloadItemIndex]
        dstColName = dstWorkloadColumnNames[workloadItemIndex]
        
        if (workload == 0) or (workload is None) or (workload is float('NaN')):
            print("총 작업량 0 (skip 합니다) : ", workload)
            continue    

        if workingDays >= 1:
            # 근무일에 고루 작업이 분배되었을 것으로 가정하고 1/N 으로 계산
            workloadPerDay = workload / workingDays

            # 계산된 작업량을 데이터프레임에 더하기
            addDailyWorkload(dfDailyHistory, dstColName,
                             workloadPerDay,
                             dtStartDate, dtEndDate,
                             entireStartDateTime, entireEndDateTime,
                             DEBUG_PRINT = DEBUG_PRINT)
        else:
            print('[%s] Working day = 0 입니다 (작업량 : %f)'%(startDateString, workload))
            continue
        
    processedRows += 1
    
print("처리된 행 수(working day = 0 포함) : ", processedRows)
print("전체 행 수 : ", len(dfExcel))
# Out:
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  33 ... (skip 합니다)
# 잘못된 착수일자 :  30 ... (skip 합니다)
# 잘못된 착수일자 :  42 ... (skip 합니다)
# 잘못된 착수일자 :  33 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  69 ... (skip 합니다)
# 잘못된 착수일자 :  69 ... (skip 합니다)
# 잘못된 착수일자 :  23 ... (skip 합니다)
# 잘못된 착수일자 :  23 ... (skip 합니다)
# 잘못된 착수일자 :  20 ... (skip 합니다)
# 잘못된 착수일자 :  20 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  4 ... (skip 합니다)
# 잘못된 착수일자 :  4 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  3 ... (skip 합니다)
# 잘못된 착수일자 :  3 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  12 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  116 ... (skip 합니다)
# 잘못된 착수일자 :  97 ... (skip 합니다)
# 잘못된 착수일자 :  138 ... (skip 합니다)
# 잘못된 착수일자 :  122 ... (skip 합니다)
# 잘못된 착수일자 :  66 ... (skip 합니다)
# 잘못된 착수일자 :  66 ... (skip 합니다)
# 잘못된 착수일자 :  56 ... (skip 합니다)
# 잘못된 착수일자 :  56 ... (skip 합니다)
# 잘못된 착수일자 :  132 ... (skip 합니다)
# 잘못된 착수일자 :  119 ... (skip 합니다)
# 잘못된 착수일자 :  40 ... (skip 합니다)
# 잘못된 착수일자 :  40 ... (skip 합니다)
# 잘못된 착수일자 :  36 ... (skip 합니다)
# 잘못된 착수일자 :  36 ... (skip 합니다)
# 잘못된 착수일자 :  43 ... (skip 합니다)
# 잘못된 착수일자 :  43 ... (skip 합니다)
# 잘못된 착수일자 :  36 ... (skip 합니다)
# 잘못된 착수일자 :  36 ... (skip 합니다)
# 잘못된 착수일자 :  128 ... (skip 합니다)
# 잘못된 착수일자 :  122 ... (skip 합니다)
# 잘못된 착수일자 :  66 ... (skip 합니다)
# 잘못된 착수일자 :  36 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  68 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  3 ... (skip 합니다)
# 잘못된 착수일자 :  3 ... (skip 합니다)
# 잘못된 착수일자 :  3 ... (skip 합니다)
# 잘못된 착수일자 :  3 ... (skip 합니다)
# 잘못된 착수일자 :  4 ... (skip 합니다)
# 잘못된 착수일자 :  4 ... (skip 합니다)
# 잘못된 착수일자 :  4 ... (skip 합니다)
# 잘못된 착수일자 :  4 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  26 ... (skip 합니다)
# 잘못된 착수일자 :  26 ... (skip 합니다)
# 잘못된 착수일자 :  97 ... (skip 합니다)
# 잘못된 착수일자 :  97 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  30 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  331 ... (skip 합니다)
# 잘못된 착수일자 :  338 ... (skip 합니다)
# 잘못된 착수일자 :  110 ... (skip 합니다)
# 잘못된 착수일자 :  122 ... (skip 합니다)
# 잘못된 착수일자 :  116 ... (skip 합니다)
# 잘못된 착수일자 :  116 ... (skip 합니다)
# 잘못된 착수일자 :  41 ... (skip 합니다)
# 잘못된 착수일자 :  34 ... (skip 합니다)
# 잘못된 착수일자 :  23 ... (skip 합니다)
# 잘못된 착수일자 :  24 ... (skip 합니다)
# 잘못된 착수일자 :  44 ... (skip 합니다)
# 잘못된 착수일자 :  58 ... (skip 합니다)
# 잘못된 착수일자 :  58 ... (skip 합니다)
# 잘못된 착수일자 :  28 ... (skip 합니다)
# 잘못된 착수일자 :  24 ... (skip 합니다)
# 잘못된 착수일자 :  179 ... (skip 합니다)
# 잘못된 착수일자 :  56 ... (skip 합니다)
# 잘못된 착수일자 :  63 ... (skip 합니다)
# 잘못된 착수일자 :  116 ... (skip 합니다)
# 잘못된 착수일자 :  31 ... (skip 합니다)
# 잘못된 착수일자 :  34 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  124 ... (skip 합니다)
# 잘못된 착수일자 :  38 ... (skip 합니다)
# 잘못된 착수일자 :  42 ... (skip 합니다)
# 잘못된 착수일자 :  200 ... (skip 합니다)
# 잘못된 착수일자 :  69 ... (skip 합니다)
# 잘못된 착수일자 :  70 ... (skip 합니다)
# 잘못된 착수일자 :  121 ... (skip 합니다)
# 잘못된 착수일자 :  35 ... (skip 합니다)
# 잘못된 착수일자 :  38 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  128 ... (skip 합니다)
# 잘못된 착수일자 :  40 ... (skip 합니다)
# 잘못된 착수일자 :  43 ... (skip 합니다)
# 잘못된 착수일자 :  206 ... (skip 합니다)
# 잘못된 착수일자 :  72 ... (skip 합니다)
# 잘못된 착수일자 :  74 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  118 ... (skip 합니다)
# 잘못된 착수일자 :  33 ... (skip 합니다)
# 잘못된 착수일자 :  36 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  117 ... (skip 합니다)
# 잘못된 착수일자 :  35 ... (skip 합니다)
# 잘못된 착수일자 :  38 ... (skip 합니다)
# 잘못된 착수일자 :  195 ... (skip 합니다)
# 잘못된 착수일자 :  63 ... (skip 합니다)
# 잘못된 착수일자 :  66 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  4 ... (skip 합니다)
# 잘못된 착수일자 :  126 ... (skip 합니다)
# 잘못된 착수일자 :  39 ... (skip 합니다)
# 잘못된 착수일자 :  43 ... (skip 합니다)
# 잘못된 착수일자 :  107 ... (skip 합니다)
# 잘못된 착수일자 :  115 ... (skip 합니다)
# 잘못된 착수일자 :  73 ... (skip 합니다)
# 잘못된 착수일자 :  76 ... (skip 합니다)
# 잘못된 착수일자 :  50 ... (skip 합니다)
# 잘못된 착수일자 :  53 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  15 ... (skip 합니다)
# 잘못된 착수일자 :  72 ... (skip 합니다)
# 잘못된 착수일자 :  73 ... (skip 합니다)
# 잘못된 착수일자 :  49 ... (skip 합니다)
# 잘못된 착수일자 :  48 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  103 ... (skip 합니다)
# 잘못된 착수일자 :  111 ... (skip 합니다)
# 잘못된 착수일자 :  70 ... (skip 합니다)
# 잘못된 착수일자 :  70 ... (skip 합니다)
# 잘못된 착수일자 :  21 ... (skip 합니다)
# 잘못된 착수일자 :  21 ... (skip 합니다)
# 잘못된 착수일자 :  75 ... (skip 합니다)
# 잘못된 착수일자 :  77 ... (skip 합니다)
# 잘못된 착수일자 :  51 ... (skip 합니다)
# 잘못된 착수일자 :  53 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  77 ... (skip 합니다)
# 잘못된 착수일자 :  74 ... (skip 합니다)
# 잘못된 착수일자 :  51 ... (skip 합니다)
# 잘못된 착수일자 :  51 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  15 ... (skip 합니다)
# 잘못된 착수일자 :  107 ... (skip 합니다)
# 잘못된 착수일자 :  107 ... (skip 합니다)
# 잘못된 착수일자 :  72 ... (skip 합니다)
# 잘못된 착수일자 :  74 ... (skip 합니다)
# 잘못된 착수일자 :  24 ... (skip 합니다)
# 잘못된 착수일자 :  24 ... (skip 합니다)
# 잘못된 착수일자 :  74 ... (skip 합니다)
# 잘못된 착수일자 :  74 ... (skip 합니다)
# 잘못된 착수일자 :  51 ... (skip 합니다)
# 잘못된 착수일자 :  51 ... (skip 합니다)
# 잘못된 착수일자 :  15 ... (skip 합니다)
# 잘못된 착수일자 :  15 ... (skip 합니다)
# 잘못된 착수일자 :  72 ... (skip 합니다)
# 잘못된 착수일자 :  72 ... (skip 합니다)
# 잘못된 착수일자 :  49 ... (skip 합니다)
# 잘못된 착수일자 :  49 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  108 ... (skip 합니다)
# 잘못된 착수일자 :  109 ... (skip 합니다)
# 잘못된 착수일자 :  75 ... (skip 합니다)
# 잘못된 착수일자 :  75 ... (skip 합니다)
# 잘못된 착수일자 :  20 ... (skip 합니다)
# 잘못된 착수일자 :  20 ... (skip 합니다)
# 잘못된 착수일자 :  79 ... (skip 합니다)
# 잘못된 착수일자 :  80 ... (skip 합니다)
# 잘못된 착수일자 :  52 ... (skip 합니다)
# 잘못된 착수일자 :  53 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  33 ... (skip 합니다)
# 잘못된 착수일자 :  46 ... (skip 합니다)
# 잘못된 착수일자 :  43 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  15 ... (skip 합니다)
# 잘못된 착수일자 :  95 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  83 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  78 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  91 ... (skip 합니다)
# 잘못된 착수일자 :  100 ... (skip 합니다)
# 잘못된 착수일자 :  72 ... (skip 합니다)
# 잘못된 착수일자 :  80 ... (skip 합니다)
# 잘못된 착수일자 :  99 ... (skip 합니다)
# 잘못된 착수일자 :  31 ... (skip 합니다)
# 잘못된 착수일자 :  41 ... (skip 합니다)
# 잘못된 착수일자 :  45 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  4 ... (skip 합니다)
# 잘못된 착수일자 :  46 ... (skip 합니다)
# 잘못된 착수일자 :  46 ... (skip 합니다)
# 잘못된 착수일자 :  20 ... (skip 합니다)
# 잘못된 착수일자 :  20 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  72 ... (skip 합니다)
# 잘못된 착수일자 :  18 ... (skip 합니다)
# 잘못된 착수일자 :  18 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  43 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  49 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  48 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  18 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  4 ... (skip 합니다)
# 잘못된 착수일자 :  36 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  31 ... (skip 합니다)
# 잘못된 착수일자 :  15 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  57 ... (skip 합니다)
# 잘못된 착수일자 :  21 ... (skip 합니다)
# 잘못된 착수일자 :  55 ... (skip 합니다)
# 잘못된 착수일자 :  55 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  116 ... (skip 합니다)
# 잘못된 착수일자 :  114 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  19 ... (skip 합니다)
# 잘못된 착수일자 :  19 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  66 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  48 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  22 ... (skip 합니다)
# 잘못된 착수일자 :  4 ... (skip 합니다)
# 잘못된 착수일자 :  3 ... (skip 합니다)
# 잘못된 착수일자 :  3 ... (skip 합니다)
# 잘못된 착수일자 :  3 ... (skip 합니다)
# 잘못된 착수일자 :  156 ... (skip 합니다)
# 잘못된 착수일자 :  156 ... (skip 합니다)
# 잘못된 착수일자 :  115 ... (skip 합니다)
# 잘못된 착수일자 :  68 ... (skip 합니다)
# 잘못된 착수일자 :  122 ... (skip 합니다)
# 잘못된 착수일자 :  104 ... (skip 합니다)
# 잘못된 착수일자 :  76 ... (skip 합니다)
# 잘못된 착수일자 :  61 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  41 ... (skip 합니다)
# 잘못된 착수일자 :  41 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  100 ... (skip 합니다)
# 잘못된 착수일자 :  48 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  333 ... (skip 합니다)
# 잘못된 착수일자 :  333 ... (skip 합니다)
# 잘못된 착수일자 :  151 ... (skip 합니다)
# 잘못된 착수일자 :  394 ... (skip 합니다)
# 잘못된 착수일자 :  394 ... (skip 합니다)
# 잘못된 착수일자 :  181 ... (skip 합니다)
# 잘못된 착수일자 :  181 ... (skip 합니다)
# 잘못된 착수일자 :  390 ... (skip 합니다)
# 잘못된 착수일자 :  390 ... (skip 합니다)
# 잘못된 착수일자 :  355 ... (skip 합니다)
# 잘못된 착수일자 :  367 ... (skip 합니다)
# 잘못된 착수일자 :  146 ... (skip 합니다)
# 잘못된 착수일자 :  146 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  257 ... (skip 합니다)
# 잘못된 착수일자 :  259 ... (skip 합니다)
# 잘못된 착수일자 :  213 ... (skip 합니다)
# 잘못된 착수일자 :  217 ... (skip 합니다)
# 잘못된 착수일자 :  287 ... (skip 합니다)
# 잘못된 착수일자 :  292 ... (skip 합니다)
# 잘못된 착수일자 :  263 ... (skip 합니다)
# 잘못된 착수일자 :  265 ... (skip 합니다)
# 잘못된 착수일자 :  178 ... (skip 합니다)
# 잘못된 착수일자 :  175 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  122 ... (skip 합니다)
# 잘못된 착수일자 :  165 ... (skip 합니다)
# 잘못된 착수일자 :  90 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  90 ... (skip 합니다)
# 잘못된 착수일자 :  95 ... (skip 합니다)
# 잘못된 착수일자 :  39 ... (skip 합니다)
# 잘못된 착수일자 :  39 ... (skip 합니다)
# 잘못된 착수일자 :  121 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  46 ... (skip 합니다)
# 잘못된 착수일자 :  3 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  143 ... (skip 합니다)
# 잘못된 착수일자 :  155 ... (skip 합니다)
# 잘못된 착수일자 :  22 ... (skip 합니다)
# 잘못된 착수일자 :  22 ... (skip 합니다)
# 잘못된 착수일자 :  144 ... (skip 합니다)
# 잘못된 착수일자 :  149 ... (skip 합니다)
# 잘못된 착수일자 :  137 ... (skip 합니다)
# 잘못된 착수일자 :  141 ... (skip 합니다)
# 잘못된 착수일자 :  30 ... (skip 합니다)
# 잘못된 착수일자 :  30 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  27 ... (skip 합니다)
# 잘못된 착수일자 :  27 ... (skip 합니다)
# 잘못된 착수일자 :  60 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  178 ... (skip 합니다)
# 잘못된 착수일자 :  165 ... (skip 합니다)
# 잘못된 착수일자 :  41 ... (skip 합니다)
# 잘못된 착수일자 :  41 ... (skip 합니다)
# 잘못된 착수일자 :  122 ... (skip 합니다)
# 잘못된 착수일자 :  115 ... (skip 합니다)
# 잘못된 착수일자 :  3 ... (skip 합니다)
# 잘못된 착수일자 :  191 ... (skip 합니다)
# 잘못된 착수일자 :  191 ... (skip 합니다)
# 잘못된 착수일자 :  320 ... (skip 합니다)
# 잘못된 착수일자 :  375 ... (skip 합니다)
# 잘못된 착수일자 :  359 ... (skip 합니다)
# 잘못된 착수일자 :  323 ... (skip 합니다)
# 잘못된 착수일자 :  235 ... (skip 합니다)
# 잘못된 착수일자 :  130 ... (skip 합니다)
# 잘못된 착수일자 :  144 ... (skip 합니다)
# 잘못된 착수일자 :  144 ... (skip 합니다)
# 잘못된 착수일자 :  174 ... (skip 합니다)
# 잘못된 착수일자 :  174 ... (skip 합니다)
# 잘못된 착수일자 :  159 ... (skip 합니다)
# 잘못된 착수일자 :  160 ... (skip 합니다)
# 잘못된 착수일자 :  160 ... (skip 합니다)
# 잘못된 착수일자 :  250 ... (skip 합니다)
# 잘못된 착수일자 :  256 ... (skip 합니다)
# 잘못된 착수일자 :  79 ... (skip 합니다)
# 잘못된 착수일자 :  85 ... (skip 합니다)
# 잘못된 착수일자 :  253 ... (skip 합니다)
# 잘못된 착수일자 :  265 ... (skip 합니다)
# 잘못된 착수일자 :  80 ... (skip 합니다)
# 잘못된 착수일자 :  92 ... (skip 합니다)
# 잘못된 착수일자 :  188 ... (skip 합니다)
# 잘못된 착수일자 :  188 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  278 ... (skip 합니다)
# 잘못된 착수일자 :  278 ... (skip 합니다)
# 잘못된 착수일자 :  158 ... (skip 합니다)
# 잘못된 착수일자 :  158 ... (skip 합니다)
# 잘못된 착수일자 :  340 ... (skip 합니다)
# 잘못된 착수일자 :  340 ... (skip 합니다)
# 잘못된 착수일자 :  184 ... (skip 합니다)
# 잘못된 착수일자 :  184 ... (skip 합니다)
# 잘못된 착수일자 :  125 ... (skip 합니다)
# 잘못된 착수일자 :  125 ... (skip 합니다)
# 잘못된 착수일자 :  56 ... (skip 합니다)
# 잘못된 착수일자 :  56 ... (skip 합니다)
# 잘못된 착수일자 :  39 ... (skip 합니다)
# 잘못된 착수일자 :  39 ... (skip 합니다)
# 잘못된 착수일자 :  71 ... (skip 합니다)
# 잘못된 착수일자 :  71 ... (skip 합니다)
# 잘못된 착수일자 :  73 ... (skip 합니다)
# 잘못된 착수일자 :  73 ... (skip 합니다)
# 잘못된 착수일자 :  28 ... (skip 합니다)
# 잘못된 착수일자 :  28 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  4 ... (skip 합니다)
# 잘못된 착수일자 :  3 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  43 ... (skip 합니다)
# 잘못된 착수일자 :  43 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  49 ... (skip 합니다)
# 잘못된 착수일자 :  68 ... (skip 합니다)
# 잘못된 착수일자 :  99 ... (skip 합니다)
# 잘못된 착수일자 :  134 ... (skip 합니다)
# 잘못된 착수일자 :  134 ... (skip 합니다)
# 잘못된 착수일자 :  195 ... (skip 합니다)
# 잘못된 착수일자 :  51 ... (skip 합니다)
# 잘못된 착수일자 :  55 ... (skip 합니다)
# 잘못된 착수일자 :  78 ... (skip 합니다)
# 잘못된 착수일자 :  78 ... (skip 합니다)
# 잘못된 착수일자 :  225 ... (skip 합니다)
# 잘못된 착수일자 :  219 ... (skip 합니다)
# 잘못된 착수일자 :  80 ... (skip 합니다)
# 잘못된 착수일자 :  80 ... (skip 합니다)
# 잘못된 착수일자 :  42 ... (skip 합니다)
# 잘못된 착수일자 :  42 ... (skip 합니다)
# 잘못된 착수일자 :  149 ... (skip 합니다)
# 잘못된 착수일자 :  121 ... (skip 합니다)
# 잘못된 착수일자 :  121 ... (skip 합니다)
# 잘못된 착수일자 :  113 ... (skip 합니다)
# 잘못된 착수일자 :  97 ... (skip 합니다)
# 잘못된 착수일자 :  64 ... (skip 합니다)
# 잘못된 착수일자 :  60 ... (skip 합니다)
# 잘못된 착수일자 :  60 ... (skip 합니다)
# 잘못된 착수일자 :  38 ... (skip 합니다)
# 잘못된 착수일자 :  36 ... (skip 합니다)
# 잘못된 착수일자 :  36 ... (skip 합니다)
# 잘못된 착수일자 :  296 ... (skip 합니다)
# 잘못된 착수일자 :  287 ... (skip 합니다)
# 잘못된 착수일자 :  207 ... (skip 합니다)
# 잘못된 착수일자 :  199 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  265 ... (skip 합니다)
# 잘못된 착수일자 :  255 ... (skip 합니다)
# 잘못된 착수일자 :  179 ... (skip 합니다)
# 잘못된 착수일자 :  172 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  119 ... (skip 합니다)
# 잘못된 착수일자 :  111 ... (skip 합니다)
# 잘못된 착수일자 :  93 ... (skip 합니다)
# 잘못된 착수일자 :  85 ... (skip 합니다)
# 잘못된 착수일자 :  28 ... (skip 합니다)
# 잘못된 착수일자 :  28 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  153 ... (skip 합니다)
# 잘못된 착수일자 :  133 ... (skip 합니다)
# 잘못된 착수일자 :  84 ... (skip 합니다)
# 잘못된 착수일자 :  68 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  159 ... (skip 합니다)
# 잘못된 착수일자 :  56 ... (skip 합니다)
# 잘못된 착수일자 :  50 ... (skip 합니다)
# 잘못된 착수일자 :  90 ... (skip 합니다)
# 잘못된 착수일자 :  98 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  15 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  18 ... (skip 합니다)
# 잘못된 착수일자 :  18 ... (skip 합니다)
# 잘못된 착수일자 :  101 ... (skip 합니다)
# 잘못된 착수일자 :  72 ... (skip 합니다)
# 잘못된 착수일자 :  72 ... (skip 합니다)
# 잘못된 착수일자 :  50 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  32 ... (skip 합니다)
# 잘못된 착수일자 :  106 ... (skip 합니다)
# 잘못된 착수일자 :  106 ... (skip 합니다)
# 잘못된 착수일자 :  41 ... (skip 합니다)
# 잘못된 착수일자 :  52 ... (skip 합니다)
# 잘못된 착수일자 :  91 ... (skip 합니다)
# 잘못된 착수일자 :  89 ... (skip 합니다)
# 잘못된 착수일자 :  99 ... (skip 합니다)
# 잘못된 착수일자 :  48 ... (skip 합니다)
# 잘못된 착수일자 :  68 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  107 ... (skip 합니다)
# 잘못된 착수일자 :  99 ... (skip 합니다)
# 잘못된 착수일자 :  24 ... (skip 합니다)
# 잘못된 착수일자 :  23 ... (skip 합니다)
# 잘못된 착수일자 :  15 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  134 ... (skip 합니다)
# 잘못된 착수일자 :  134 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  4 ... (skip 합니다)
# 잘못된 착수일자 :  195 ... (skip 합니다)
# 잘못된 착수일자 :  81 ... (skip 합니다)
# 잘못된 착수일자 :  114 ... (skip 합니다)
# 잘못된 착수일자 :  54 ... (skip 합니다)
# 잘못된 착수일자 :  23 ... (skip 합니다)
# 잘못된 착수일자 :  24 ... (skip 합니다)
# 잘못된 착수일자 :  84 ... (skip 합니다)
# 잘못된 착수일자 :  91 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  35 ... (skip 합니다)
# 잘못된 착수일자 :  35 ... (skip 합니다)
# 잘못된 착수일자 :  20 ... (skip 합니다)
# 잘못된 착수일자 :  20 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  64 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  60 ... (skip 합니다)
# 잘못된 착수일자 :  65 ... (skip 합니다)
# 잘못된 착수일자 :  15 ... (skip 합니다)
# 잘못된 착수일자 :  15 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  51 ... (skip 합니다)
# 잘못된 착수일자 :  55 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  55 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  78 ... (skip 합니다)
# 잘못된 착수일자 :  78 ... (skip 합니다)
# 잘못된 착수일자 :  3 ... (skip 합니다)
# 잘못된 착수일자 :  3 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  25 ... (skip 합니다)
# 잘못된 착수일자 :  25 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  70 ... (skip 합니다)
# 잘못된 착수일자 :  61 ... (skip 합니다)
# 잘못된 착수일자 :  24 ... (skip 합니다)
# 잘못된 착수일자 :  24 ... (skip 합니다)
# 잘못된 착수일자 :  18 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  54 ... (skip 합니다)
# 잘못된 착수일자 :  54 ... (skip 합니다)
# 잘못된 착수일자 :  59 ... (skip 합니다)
# 잘못된 착수일자 :  59 ... (skip 합니다)
# 잘못된 착수일자 :  55 ... (skip 합니다)
# 잘못된 착수일자 :  55 ... (skip 합니다)
# 잘못된 착수일자 :  80 ... (skip 합니다)
# 잘못된 착수일자 :  80 ... (skip 합니다)
# 잘못된 착수일자 :  373 ... (skip 합니다)
# 잘못된 착수일자 :  373 ... (skip 합니다)
# 잘못된 착수일자 :  135 ... (skip 합니다)
# 잘못된 착수일자 :  135 ... (skip 합니다)
# 잘못된 착수일자 :  33 ... (skip 합니다)
# 잘못된 착수일자 :  33 ... (skip 합니다)
# 잘못된 착수일자 :  404 ... (skip 합니다)
# 잘못된 착수일자 :  400 ... (skip 합니다)
# 잘못된 착수일자 :  157 ... (skip 합니다)
# 잘못된 착수일자 :  157 ... (skip 합니다)
# 잘못된 착수일자 :  35 ... (skip 합니다)
# 잘못된 착수일자 :  35 ... (skip 합니다)
# 잘못된 착수일자 :  149 ... (skip 합니다)
# 잘못된 착수일자 :  149 ... (skip 합니다)
# 잘못된 착수일자 :  36 ... (skip 합니다)
# 잘못된 착수일자 :  36 ... (skip 합니다)
# 잘못된 착수일자 :  36 ... (skip 합니다)
# 잘못된 착수일자 :  36 ... (skip 합니다)
# 잘못된 착수일자 :  38 ... (skip 합니다)
# 잘못된 착수일자 :  38 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  215 ... (skip 합니다)
# 잘못된 착수일자 :  215 ... (skip 합니다)
# 잘못된 착수일자 :  83 ... (skip 합니다)
# 잘못된 착수일자 :  83 ... (skip 합니다)
# 잘못된 착수일자 :  63 ... (skip 합니다)
# 잘못된 착수일자 :  63 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  35 ... (skip 합니다)
# 잘못된 착수일자 :  35 ... (skip 합니다)
# 잘못된 착수일자 :  155 ... (skip 합니다)
# 잘못된 착수일자 :  155 ... (skip 합니다)
# 잘못된 착수일자 :  63 ... (skip 합니다)
# 잘못된 착수일자 :  63 ... (skip 합니다)
# 잘못된 착수일자 :  127 ... (skip 합니다)
# 잘못된 착수일자 :  127 ... (skip 합니다)
# 잘못된 착수일자 :  41 ... (skip 합니다)
# 잘못된 착수일자 :  41 ... (skip 합니다)
# 잘못된 착수일자 :  25 ... (skip 합니다)
# 잘못된 착수일자 :  25 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  67 ... (skip 합니다)
# 잘못된 착수일자 :  63 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  114 ... (skip 합니다)
# 잘못된 착수일자 :  97 ... (skip 합니다)
# 잘못된 착수일자 :  38 ... (skip 합니다)
# 잘못된 착수일자 :  34 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  47 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  61 ... (skip 합니다)
# 잘못된 착수일자 :  65 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  57 ... (skip 합니다)
# 잘못된 착수일자 :  51 ... (skip 합니다)
# 잘못된 착수일자 :  94 ... (skip 합니다)
# 잘못된 착수일자 :  81 ... (skip 합니다)
# 잘못된 착수일자 :  23 ... (skip 합니다)
# 잘못된 착수일자 :  21 ... (skip 합니다)
# 잘못된 착수일자 :  19 ... (skip 합니다)
# 잘못된 착수일자 :  19 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  128 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  38 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  146 ... (skip 합니다)
# 잘못된 착수일자 :  52 ... (skip 합니다)
# 잘못된 착수일자 :  52 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  3 ... (skip 합니다)
# 잘못된 착수일자 :  3 ... (skip 합니다)
# 잘못된 착수일자 :  293 ... (skip 합니다)
# 잘못된 착수일자 :  73 ... (skip 합니다)
# 잘못된 착수일자 :  81 ... (skip 합니다)
# 잘못된 착수일자 :  101 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  4 ... (skip 합니다)
# 잘못된 착수일자 :  4 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  4 ... (skip 합니다)
# 잘못된 착수일자 :  4 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  84 ... (skip 합니다)
# 잘못된 착수일자 :  60 ... (skip 합니다)
# 잘못된 착수일자 :  60 ... (skip 합니다)
# 잘못된 착수일자 :  23 ... (skip 합니다)
# 잘못된 착수일자 :  24 ... (skip 합니다)
# 잘못된 착수일자 :  213 ... (skip 합니다)
# 잘못된 착수일자 :  194 ... (skip 합니다)
# 잘못된 착수일자 :  74 ... (skip 합니다)
# 잘못된 착수일자 :  73 ... (skip 합니다)
# 잘못된 착수일자 :  21 ... (skip 합니다)
# 잘못된 착수일자 :  19 ... (skip 합니다)
# 잘못된 착수일자 :  22 ... (skip 합니다)
# 잘못된 착수일자 :  20 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  38 ... (skip 합니다)
# 잘못된 착수일자 :  36 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  43 ... (skip 합니다)
# 잘못된 착수일자 :  43 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  36 ... (skip 합니다)
# 잘못된 착수일자 :  257 ... (skip 합니다)
# 잘못된 착수일자 :  249 ... (skip 합니다)
# 잘못된 착수일자 :  177 ... (skip 합니다)
# 잘못된 착수일자 :  170 ... (skip 합니다)
# 잘못된 착수일자 :  44 ... (skip 합니다)
# 잘못된 착수일자 :  44 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  274 ... (skip 합니다)
# 잘못된 착수일자 :  266 ... (skip 합니다)
# 잘못된 착수일자 :  192 ... (skip 합니다)
# 잘못된 착수일자 :  184 ... (skip 합니다)
# 잘못된 착수일자 :  50 ... (skip 합니다)
# 잘못된 착수일자 :  50 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  296 ... (skip 합니다)
# 잘못된 착수일자 :  287 ... (skip 합니다)
# 잘못된 착수일자 :  207 ... (skip 합니다)
# 잘못된 착수일자 :  199 ... (skip 합니다)
# 잘못된 착수일자 :  54 ... (skip 합니다)
# 잘못된 착수일자 :  53 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  265 ... (skip 합니다)
# 잘못된 착수일자 :  255 ... (skip 합니다)
# 잘못된 착수일자 :  179 ... (skip 합니다)
# 잘못된 착수일자 :  172 ... (skip 합니다)
# 잘못된 착수일자 :  41 ... (skip 합니다)
# 잘못된 착수일자 :  41 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  84 ... (skip 합니다)
# 잘못된 착수일자 :  68 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  159 ... (skip 합니다)
# 잘못된 착수일자 :  49 ... (skip 합니다)
# 잘못된 착수일자 :  56 ... (skip 합니다)
# 잘못된 착수일자 :  50 ... (skip 합니다)
# 잘못된 착수일자 :  26 ... (skip 합니다)
# 잘못된 착수일자 :  26 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  239 ... (skip 합니다)
# 잘못된 착수일자 :  188 ... (skip 합니다)
# 잘못된 착수일자 :  30 ... (skip 합니다)
# 잘못된 착수일자 :  50 ... (skip 합니다)
# 잘못된 착수일자 :  49 ... (skip 합니다)
# 잘못된 착수일자 :  223 ... (skip 합니다)
# 잘못된 착수일자 :  155 ... (skip 합니다)
# 잘못된 착수일자 :  48 ... (skip 합니다)
# 잘못된 착수일자 :  148 ... (skip 합니다)
# 잘못된 착수일자 :  147 ... (skip 합니다)
# 잘못된 착수일자 :  79 ... (skip 합니다)
# 잘못된 착수일자 :  79 ... (skip 합니다)
# 잘못된 착수일자 :  48 ... (skip 합니다)
# 잘못된 착수일자 :  48 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  60 ... (skip 합니다)
# 잘못된 착수일자 :  60 ... (skip 합니다)
# 잘못된 착수일자 :  101 ... (skip 합니다)
# 잘못된 착수일자 :  94 ... (skip 합니다)
# 잘못된 착수일자 :  4 ... (skip 합니다)
# 잘못된 착수일자 :  52 ... (skip 합니다)
# 잘못된 착수일자 :  52 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  72 ... (skip 합니다)
# 잘못된 착수일자 :  72 ... (skip 합니다)
# 잘못된 착수일자 :  32 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  110 ... (skip 합니다)
# 잘못된 착수일자 :  102 ... (skip 합니다)
# 잘못된 착수일자 :  25 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  18 ... (skip 합니다)
# 잘못된 착수일자 :  18 ... (skip 합니다)
# 잘못된 착수일자 :  30 ... (skip 합니다)
# 잘못된 착수일자 :  30 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  144 ... (skip 합니다)
# 잘못된 착수일자 :  137 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  43 ... (skip 합니다)
# 잘못된 착수일자 :  43 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  19 ... (skip 합니다)
# 잘못된 착수일자 :  3 ... (skip 합니다)
# 잘못된 착수일자 :  98 ... (skip 합니다)
# 잘못된 착수일자 :  98 ... (skip 합니다)
# 잘못된 착수일자 :  4 ... (skip 합니다)
# 잘못된 착수일자 :  4 ... (skip 합니다)
# 잘못된 착수일자 :  38 ... (skip 합니다)
# 잘못된 착수일자 :  38 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  80 ... (skip 합니다)
# 잘못된 착수일자 :  80 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  32 ... (skip 합니다)
# 잘못된 착수일자 :  32 ... (skip 합니다)
# 잘못된 착수일자 :  24 ... (skip 합니다)
# 잘못된 착수일자 :  24 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  4 ... (skip 합니다)
# 잘못된 착수일자 :  4 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  41 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  52 ... (skip 합니다)
# 잘못된 착수일자 :  46 ... (skip 합니다)
# 잘못된 착수일자 :  19 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  91 ... (skip 합니다)
# 잘못된 착수일자 :  89 ... (skip 합니다)
# 잘못된 착수일자 :  32 ... (skip 합니다)
# 잘못된 착수일자 :  29 ... (skip 합니다)
# 잘못된 착수일자 :  27 ... (skip 합니다)
# 잘못된 착수일자 :  26 ... (skip 합니다)
# 잘못된 착수일자 :  155 ... (skip 합니다)
# 잘못된 착수일자 :  153 ... (skip 합니다)
# 잘못된 착수일자 :  65 ... (skip 합니다)
# 잘못된 착수일자 :  63 ... (skip 합니다)
# 잘못된 착수일자 :  34 ... (skip 합니다)
# 잘못된 착수일자 :  32 ... (skip 합니다)
# 잘못된 착수일자 :  99 ... (skip 합니다)
# 잘못된 착수일자 :  38 ... (skip 합니다)
# 잘못된 착수일자 :  27 ... (skip 합니다)
# 잘못된 착수일자 :  48 ... (skip 합니다)
# 잘못된 착수일자 :  68 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  107 ... (skip 합니다)
# 잘못된 착수일자 :  99 ... (skip 합니다)
# 잘못된 착수일자 :  24 ... (skip 합니다)
# 잘못된 착수일자 :  23 ... (skip 합니다)
# 잘못된 착수일자 :  15 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  134 ... (skip 합니다)
# 잘못된 착수일자 :  134 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  4 ... (skip 합니다)
# 잘못된 착수일자 :  195 ... (skip 합니다)
# 잘못된 착수일자 :  81 ... (skip 합니다)
# 잘못된 착수일자 :  114 ... (skip 합니다)
# 잘못된 착수일자 :  22 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  15 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  40 ... (skip 합니다)
# 잘못된 착수일자 :  21 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  25 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  100 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  23 ... (skip 합니다)
# 잘못된 착수일자 :  23 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  54 ... (skip 합니다)
# 잘못된 착수일자 :  23 ... (skip 합니다)
# 잘못된 착수일자 :  24 ... (skip 합니다)
# 잘못된 착수일자 :  129 ... (skip 합니다)
# 잘못된 착수일자 :  52 ... (skip 합니다)
# 잘못된 착수일자 :  23 ... (skip 합니다)
# 잘못된 착수일자 :  53 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  84 ... (skip 합니다)
# 잘못된 착수일자 :  91 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  35 ... (skip 합니다)
# 잘못된 착수일자 :  35 ... (skip 합니다)
# 잘못된 착수일자 :  20 ... (skip 합니다)
# 잘못된 착수일자 :  20 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  64 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  55 ... (skip 합니다)
# 잘못된 착수일자 :  54 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  56 ... (skip 합니다)
# 잘못된 착수일자 :  56 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  60 ... (skip 합니다)
# 잘못된 착수일자 :  65 ... (skip 합니다)
# 잘못된 착수일자 :  15 ... (skip 합니다)
# 잘못된 착수일자 :  15 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  54 ... (skip 합니다)
# 잘못된 착수일자 :  54 ... (skip 합니다)
# 잘못된 착수일자 :  22 ... (skip 합니다)
# 잘못된 착수일자 :  22 ... (skip 합니다)
# 잘못된 착수일자 :  51 ... (skip 합니다)
# 잘못된 착수일자 :  55 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  55 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  78 ... (skip 합니다)
# 잘못된 착수일자 :  78 ... (skip 합니다)
# 잘못된 착수일자 :  3 ... (skip 합니다)
# 잘못된 착수일자 :  3 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  25 ... (skip 합니다)
# 잘못된 착수일자 :  25 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  70 ... (skip 합니다)
# 잘못된 착수일자 :  61 ... (skip 합니다)
# 잘못된 착수일자 :  24 ... (skip 합니다)
# 잘못된 착수일자 :  24 ... (skip 합니다)
# 잘못된 착수일자 :  18 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  92 ... (skip 합니다)
# 잘못된 착수일자 :  92 ... (skip 합니다)
# 잘못된 착수일자 :  52 ... (skip 합니다)
# 잘못된 착수일자 :  52 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  52 ... (skip 합니다)
# 잘못된 착수일자 :  52 ... (skip 합니다)
# 잘못된 착수일자 :  80 ... (skip 합니다)
# 잘못된 착수일자 :  80 ... (skip 합니다)
# 잘못된 착수일자 :  42 ... (skip 합니다)
# 잘못된 착수일자 :  42 ... (skip 합니다)
# 잘못된 착수일자 :  85 ... (skip 합니다)
# 잘못된 착수일자 :  85 ... (skip 합니다)
# 잘못된 착수일자 :  51 ... (skip 합니다)
# 잘못된 착수일자 :  51 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  60 ... (skip 합니다)
# 잘못된 착수일자 :  60 ... (skip 합니다)
# 잘못된 착수일자 :  28 ... (skip 합니다)
# 잘못된 착수일자 :  28 ... (skip 합니다)
# 잘못된 착수일자 :  25 ... (skip 합니다)
# 잘못된 착수일자 :  33 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  27 ... (skip 합니다)
# 잘못된 착수일자 :  31 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  28 ... (skip 합니다)
# 잘못된 착수일자 :  30 ... (skip 합니다)
# 잘못된 착수일자 :  27 ... (skip 합니다)
# 잘못된 착수일자 :  29 ... (skip 합니다)
# 잘못된 착수일자 :  28 ... (skip 합니다)
# 잘못된 착수일자 :  29 ... (skip 합니다)
# 잘못된 착수일자 :  28 ... (skip 합니다)
# 잘못된 착수일자 :  30 ... (skip 합니다)
# 잘못된 착수일자 :  27 ... (skip 합니다)
# 잘못된 착수일자 :  29 ... (skip 합니다)
# 잘못된 착수일자 :  32 ... (skip 합니다)
# 잘못된 착수일자 :  33 ... (skip 합니다)
# 잘못된 착수일자 :  46 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  109 ... (skip 합니다)
# 잘못된 착수일자 :  109 ... (skip 합니다)
# 잘못된 착수일자 :  50 ... (skip 합니다)
# 잘못된 착수일자 :  50 ... (skip 합니다)
# 잘못된 착수일자 :  25 ... (skip 합니다)
# 잘못된 착수일자 :  25 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  144 ... (skip 합니다)
# 잘못된 착수일자 :  144 ... (skip 합니다)
# 잘못된 착수일자 :  60 ... (skip 합니다)
# 잘못된 착수일자 :  60 ... (skip 합니다)
# 잘못된 착수일자 :  36 ... (skip 합니다)
# 잘못된 착수일자 :  36 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  411 ... (skip 합니다)
# 잘못된 착수일자 :  411 ... (skip 합니다)
# 잘못된 착수일자 :  151 ... (skip 합니다)
# 잘못된 착수일자 :  151 ... (skip 합니다)
# 잘못된 착수일자 :  133 ... (skip 합니다)
# 잘못된 착수일자 :  133 ... (skip 합니다)
# 잘못된 착수일자 :  36 ... (skip 합니다)
# 잘못된 착수일자 :  36 ... (skip 합니다)
# 잘못된 착수일자 :  78 ... (skip 합니다)
# 잘못된 착수일자 :  78 ... (skip 합니다)
# 잘못된 착수일자 :  34 ... (skip 합니다)
# 잘못된 착수일자 :  34 ... (skip 합니다)
# 잘못된 착수일자 :  404 ... (skip 합니다)
# 잘못된 착수일자 :  400 ... (skip 합니다)
# 잘못된 착수일자 :  157 ... (skip 합니다)
# 잘못된 착수일자 :  157 ... (skip 합니다)
# 잘못된 착수일자 :  124 ... (skip 합니다)
# 잘못된 착수일자 :  125 ... (skip 합니다)
# 잘못된 착수일자 :  35 ... (skip 합니다)
# 잘못된 착수일자 :  35 ... (skip 합니다)
# 잘못된 착수일자 :  77 ... (skip 합니다)
# 잘못된 착수일자 :  77 ... (skip 합니다)
# 잘못된 착수일자 :  120 ... (skip 합니다)
# 잘못된 착수일자 :  120 ... (skip 합니다)
# 잘못된 착수일자 :  33 ... (skip 합니다)
# 잘못된 착수일자 :  33 ... (skip 합니다)
# 잘못된 착수일자 :  30 ... (skip 합니다)
# 잘못된 착수일자 :  30 ... (skip 합니다)
# 잘못된 착수일자 :  25 ... (skip 합니다)
# 잘못된 착수일자 :  25 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  215 ... (skip 합니다)
# 잘못된 착수일자 :  215 ... (skip 합니다)
# 잘못된 착수일자 :  83 ... (skip 합니다)
# 잘못된 착수일자 :  83 ... (skip 합니다)
# 잘못된 착수일자 :  63 ... (skip 합니다)
# 잘못된 착수일자 :  63 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  35 ... (skip 합니다)
# 잘못된 착수일자 :  35 ... (skip 합니다)
# 잘못된 착수일자 :  67 ... (skip 합니다)
# 잘못된 착수일자 :  63 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  114 ... (skip 합니다)
# 잘못된 착수일자 :  97 ... (skip 합니다)
# 잘못된 착수일자 :  38 ... (skip 합니다)
# 잘못된 착수일자 :  34 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  47 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  61 ... (skip 합니다)
# 잘못된 착수일자 :  65 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  57 ... (skip 합니다)
# 잘못된 착수일자 :  51 ... (skip 합니다)
# 잘못된 착수일자 :  24 ... (skip 합니다)
# 잘못된 착수일자 :  26 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  94 ... (skip 합니다)
# 잘못된 착수일자 :  81 ... (skip 합니다)
# 잘못된 착수일자 :  23 ... (skip 합니다)
# 잘못된 착수일자 :  21 ... (skip 합니다)
# 잘못된 착수일자 :  20 ... (skip 합니다)
# 잘못된 착수일자 :  18 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  108 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  3 ... (skip 합니다)
# 잘못된 착수일자 :  293 ... (skip 합니다)
# 잘못된 착수일자 :  73 ... (skip 합니다)
# 잘못된 착수일자 :  81 ... (skip 합니다)
# 잘못된 착수일자 :  101 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  4 ... (skip 합니다)
# 잘못된 착수일자 :  4 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  4 ... (skip 합니다)
# 잘못된 착수일자 :  4 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  84 ... (skip 합니다)
# 잘못된 착수일자 :  38 ... (skip 합니다)
# 잘못된 착수일자 :  36 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  43 ... (skip 합니다)
# 잘못된 착수일자 :  43 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  36 ... (skip 합니다)
# 잘못된 착수일자 :  135 ... (skip 합니다)
# 잘못된 착수일자 :  128 ... (skip 합니다)
# 잘못된 착수일자 :  101 ... (skip 합니다)
# 잘못된 착수일자 :  95 ... (skip 합니다)
# 잘못된 착수일자 :  34 ... (skip 합니다)
# 잘못된 착수일자 :  34 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  213 ... (skip 합니다)
# 잘못된 착수일자 :  203 ... (skip 합니다)
# 잘못된 착수일자 :  150 ... (skip 합니다)
# 잘못된 착수일자 :  142 ... (skip 합니다)
# 잘못된 착수일자 :  36 ... (skip 합니다)
# 잘못된 착수일자 :  36 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  296 ... (skip 합니다)
# 잘못된 착수일자 :  287 ... (skip 합니다)
# 잘못된 착수일자 :  207 ... (skip 합니다)
# 잘못된 착수일자 :  199 ... (skip 합니다)
# 잘못된 착수일자 :  54 ... (skip 합니다)
# 잘못된 착수일자 :  53 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  265 ... (skip 합니다)
# 잘못된 착수일자 :  255 ... (skip 합니다)
# 잘못된 착수일자 :  179 ... (skip 합니다)
# 잘못된 착수일자 :  172 ... (skip 합니다)
# 잘못된 착수일자 :  41 ... (skip 합니다)
# 잘못된 착수일자 :  41 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  119 ... (skip 합니다)
# 잘못된 착수일자 :  111 ... (skip 합니다)
# 잘못된 착수일자 :  93 ... (skip 합니다)
# 잘못된 착수일자 :  85 ... (skip 합니다)
# 잘못된 착수일자 :  28 ... (skip 합니다)
# 잘못된 착수일자 :  28 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  153 ... (skip 합니다)
# 잘못된 착수일자 :  133 ... (skip 합니다)
# 잘못된 착수일자 :  33 ... (skip 합니다)
# 잘못된 착수일자 :  33 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  84 ... (skip 합니다)
# 잘못된 착수일자 :  68 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  159 ... (skip 합니다)
# 잘못된 착수일자 :  49 ... (skip 합니다)
# 잘못된 착수일자 :  56 ... (skip 합니다)
# 잘못된 착수일자 :  50 ... (skip 합니다)
# 잘못된 착수일자 :  26 ... (skip 합니다)
# 잘못된 착수일자 :  26 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  142 ... (skip 합니다)
# 잘못된 착수일자 :  147 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  15 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  24 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  90 ... (skip 합니다)
# 잘못된 착수일자 :  99 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  15 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  18 ... (skip 합니다)
# 잘못된 착수일자 :  18 ... (skip 합니다)
# 잘못된 착수일자 :  78 ... (skip 합니다)
# 잘못된 착수일자 :  84 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  20 ... (skip 합니다)
# 잘못된 착수일자 :  25 ... (skip 합니다)
# 잘못된 착수일자 :  26 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  60 ... (skip 합니다)
# 잘못된 착수일자 :  60 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  155 ... (skip 합니다)
# 잘못된 착수일자 :  148 ... (skip 합니다)
# 잘못된 착수일자 :  3 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  15 ... (skip 합니다)
# 잘못된 착수일자 :  15 ... (skip 합니다)
# 잘못된 착수일자 :  72 ... (skip 합니다)
# 잘못된 착수일자 :  71 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  101 ... (skip 합니다)
# 잘못된 착수일자 :  94 ... (skip 합니다)
# 잘못된 착수일자 :  4 ... (skip 합니다)
# 잘못된 착수일자 :  52 ... (skip 합니다)
# 잘못된 착수일자 :  52 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  72 ... (skip 합니다)
# 잘못된 착수일자 :  72 ... (skip 합니다)
# 잘못된 착수일자 :  50 ... (skip 합니다)
# 잘못된 착수일자 :  50 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  32 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  110 ... (skip 합니다)
# 잘못된 착수일자 :  102 ... (skip 합니다)
# 잘못된 착수일자 :  25 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  18 ... (skip 합니다)
# 잘못된 착수일자 :  18 ... (skip 합니다)
# 잘못된 착수일자 :  30 ... (skip 합니다)
# 잘못된 착수일자 :  30 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  144 ... (skip 합니다)
# 잘못된 착수일자 :  137 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  43 ... (skip 합니다)
# 잘못된 착수일자 :  43 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  19 ... (skip 합니다)
# 잘못된 착수일자 :  19 ... (skip 합니다)
# 잘못된 착수일자 :  3 ... (skip 합니다)
# 잘못된 착수일자 :  41 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  52 ... (skip 합니다)
# 잘못된 착수일자 :  46 ... (skip 합니다)
# 잘못된 착수일자 :  19 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  93 ... (skip 합니다)
# 잘못된 착수일자 :  99 ... (skip 합니다)
# 잘못된 착수일자 :  21 ... (skip 합니다)
# 잘못된 착수일자 :  26 ... (skip 합니다)
# ...
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  4 ... (skip 합니다)
# 잘못된 착수일자 :  4 ... (skip 합니다)
# 잘못된 착수일자 :  47 ... (skip 합니다)
# 잘못된 착수일자 :  47 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  15 ... (skip 합니다)
# 잘못된 착수일자 :  15 ... (skip 합니다)
# 잘못된 착수일자 :  50 ... (skip 합니다)
# 잘못된 착수일자 :  50 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  23 ... (skip 합니다)
# 잘못된 착수일자 :  23 ... (skip 합니다)
# 잘못된 착수일자 :  38 ... (skip 합니다)
# 잘못된 착수일자 :  38 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  36 ... (skip 합니다)
# 잘못된 착수일자 :  19 ... (skip 합니다)
# 잘못된 착수일자 :  68 ... (skip 합니다)
# 잘못된 착수일자 :  68 ... (skip 합니다)
# 잘못된 착수일자 :  28 ... (skip 합니다)
# 잘못된 착수일자 :  28 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  151 ... (skip 합니다)
# 잘못된 착수일자 :  131 ... (skip 합니다)
# 잘못된 착수일자 :  15 ... (skip 합니다)
# 잘못된 착수일자 :  15 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  15 ... (skip 합니다)
# 잘못된 착수일자 :  196 ... (skip 합니다)
# 잘못된 착수일자 :  185 ... (skip 합니다)
# 잘못된 착수일자 :  129 ... (skip 합니다)
# 잘못된 착수일자 :  120 ... (skip 합니다)
# 잘못된 착수일자 :  18 ... (skip 합니다)
# 잘못된 착수일자 :  18 ... (skip 합니다)
# 잘못된 착수일자 :  207 ... (skip 합니다)
# 잘못된 착수일자 :  194 ... (skip 합니다)
# 잘못된 착수일자 :  147 ... (skip 합니다)
# 잘못된 착수일자 :  133 ... (skip 합니다)
# 잘못된 착수일자 :  22 ... (skip 합니다)
# 잘못된 착수일자 :  21 ... (skip 합니다)
# 잘못된 착수일자 :  196 ... (skip 합니다)
# 잘못된 착수일자 :  185 ... (skip 합니다)
# 잘못된 착수일자 :  125 ... (skip 합니다)
# 잘못된 착수일자 :  116 ... (skip 합니다)
# 잘못된 착수일자 :  18 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  172 ... (skip 합니다)
# 잘못된 착수일자 :  165 ... (skip 합니다)
# 잘못된 착수일자 :  66 ... (skip 합니다)
# 잘못된 착수일자 :  58 ... (skip 합니다)
# 잘못된 착수일자 :  80 ... (skip 합니다)
# 잘못된 착수일자 :  80 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  71 ... (skip 합니다)
# 잘못된 착수일자 :  71 ... (skip 합니다)
# 잘못된 착수일자 :  53 ... (skip 합니다)
# 잘못된 착수일자 :  53 ... (skip 합니다)
# 잘못된 착수일자 :  148 ... (skip 합니다)
# 잘못된 착수일자 :  47 ... (skip 합니다)
# 잘못된 착수일자 :  49 ... (skip 합니다)
# 잘못된 착수일자 :  120 ... (skip 합니다)
# 잘못된 착수일자 :  32 ... (skip 합니다)
# 잘못된 착수일자 :  34 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  116 ... (skip 합니다)
# 잘못된 착수일자 :  36 ... (skip 합니다)
# 잘못된 착수일자 :  34 ... (skip 합니다)
# 잘못된 착수일자 :  177 ... (skip 합니다)
# 잘못된 착수일자 :  60 ... (skip 합니다)
# 잘못된 착수일자 :  60 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  111 ... (skip 합니다)
# 잘못된 착수일자 :  31 ... (skip 합니다)
# 잘못된 착수일자 :  32 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  114 ... (skip 합니다)
# 잘못된 착수일자 :  36 ... (skip 합니다)
# 잘못된 착수일자 :  34 ... (skip 합니다)
# 잘못된 착수일자 :  165 ... (skip 합니다)
# 잘못된 착수일자 :  55 ... (skip 합니다)
# 잘못된 착수일자 :  53 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  105 ... (skip 합니다)
# 잘못된 착수일자 :  30 ... (skip 합니다)
# 잘못된 착수일자 :  31 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  108 ... (skip 합니다)
# 잘못된 착수일자 :  33 ... (skip 합니다)
# 잘못된 착수일자 :  31 ... (skip 합니다)
# 잘못된 착수일자 :  124 ... (skip 합니다)
# 잘못된 착수일자 :  41 ... (skip 합니다)
# 잘못된 착수일자 :  40 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  140 ... (skip 합니다)
# 잘못된 착수일자 :  45 ... (skip 합니다)
# 잘못된 착수일자 :  43 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  96 ... (skip 합니다)
# 잘못된 착수일자 :  98 ... (skip 합니다)
# 잘못된 착수일자 :  63 ... (skip 합니다)
# 잘못된 착수일자 :  65 ... (skip 합니다)
# 잘못된 착수일자 :  18 ... (skip 합니다)
# 잘못된 착수일자 :  19 ... (skip 합니다)
# 잘못된 착수일자 :  78 ... (skip 합니다)
# 잘못된 착수일자 :  79 ... (skip 합니다)
# 잘못된 착수일자 :  53 ... (skip 합니다)
# 잘못된 착수일자 :  55 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  75 ... (skip 합니다)
# 잘못된 착수일자 :  76 ... (skip 합니다)
# 잘못된 착수일자 :  51 ... (skip 합니다)
# 잘못된 착수일자 :  52 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  100 ... (skip 합니다)
# 잘못된 착수일자 :  102 ... (skip 합니다)
# 잘못된 착수일자 :  68 ... (skip 합니다)
# 잘못된 착수일자 :  71 ... (skip 합니다)
# 잘못된 착수일자 :  20 ... (skip 합니다)
# 잘못된 착수일자 :  21 ... (skip 합니다)
# 잘못된 착수일자 :  75 ... (skip 합니다)
# 잘못된 착수일자 :  78 ... (skip 합니다)
# 잘못된 착수일자 :  51 ... (skip 합니다)
# 잘못된 착수일자 :  52 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  77 ... (skip 합니다)
# 잘못된 착수일자 :  75 ... (skip 합니다)
# 잘못된 착수일자 :  54 ... (skip 합니다)
# 잘못된 착수일자 :  51 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  15 ... (skip 합니다)
# 잘못된 착수일자 :  103 ... (skip 합니다)
# 잘못된 착수일자 :  103 ... (skip 합니다)
# 잘못된 착수일자 :  71 ... (skip 합니다)
# 잘못된 착수일자 :  71 ... (skip 합니다)
# 잘못된 착수일자 :  23 ... (skip 합니다)
# 잘못된 착수일자 :  22 ... (skip 합니다)
# 잘못된 착수일자 :  74 ... (skip 합니다)
# 잘못된 착수일자 :  74 ... (skip 합니다)
# 잘못된 착수일자 :  49 ... (skip 합니다)
# 잘못된 착수일자 :  49 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  73 ... (skip 합니다)
# 잘못된 착수일자 :  73 ... (skip 합니다)
# 잘못된 착수일자 :  50 ... (skip 합니다)
# 잘못된 착수일자 :  50 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  80 ... (skip 합니다)
# 잘못된 착수일자 :  80 ... (skip 합니다)
# 잘못된 착수일자 :  51 ... (skip 합니다)
# 잘못된 착수일자 :  51 ... (skip 합니다)
# 잘못된 착수일자 :  15 ... (skip 합니다)
# 잘못된 착수일자 :  15 ... (skip 합니다)
# 잘못된 착수일자 :  96 ... (skip 합니다)
# 잘못된 착수일자 :  96 ... (skip 합니다)
# 잘못된 착수일자 :  59 ... (skip 합니다)
# 잘못된 착수일자 :  59 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  48 ... (skip 합니다)
# 잘못된 착수일자 :  3 ... (skip 합니다)
# 잘못된 착수일자 :  3 ... (skip 합니다)
# 잘못된 착수일자 :  4 ... (skip 합니다)
# 잘못된 착수일자 :  36 ... (skip 합니다)
# 잘못된 착수일자 :  3 ... (skip 합니다)
# 잘못된 착수일자 :  3 ... (skip 합니다)
# 잘못된 착수일자 :  3 ... (skip 합니다)
# 잘못된 착수일자 :  49 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  3 ... (skip 합니다)
# 잘못된 착수일자 :  3 ... (skip 합니다)
# 잘못된 착수일자 :  22 ... (skip 합니다)
# 잘못된 착수일자 :  146 ... (skip 합니다)
# 잘못된 착수일자 :  21 ... (skip 합니다)
# 잘못된 착수일자 :  15 ... (skip 합니다)
# 잘못된 착수일자 :  20 ... (skip 합니다)
# 잘못된 착수일자 :  21 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  95 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  70 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  264 ... (skip 합니다)
# 잘못된 착수일자 :  263 ... (skip 합니다)
# 잘못된 착수일자 :  24 ... (skip 합니다)
# 잘못된 착수일자 :  24 ... (skip 합니다)
# 잘못된 착수일자 :  67 ... (skip 합니다)
# 잘못된 착수일자 :  69 ... (skip 합니다)
# 잘못된 착수일자 :  80 ... (skip 합니다)
# 잘못된 착수일자 :  81 ... (skip 합니다)
# 잘못된 착수일자 :  36 ... (skip 합니다)
# 잘못된 착수일자 :  39 ... (skip 합니다)
# 잘못된 착수일자 :  22 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  23 ... (skip 합니다)
# 잘못된 착수일자 :  23 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  30 ... (skip 합니다)
# 잘못된 착수일자 :  30 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  18 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  55 ... (skip 합니다)
# 잘못된 착수일자 :  57 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  42 ... (skip 합니다)
# 잘못된 착수일자 :  42 ... (skip 합니다)
# 잘못된 착수일자 :  26 ... (skip 합니다)
# 잘못된 착수일자 :  26 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  76 ... (skip 합니다)
# 잘못된 착수일자 :  76 ... (skip 합니다)
# 잘못된 착수일자 :  4 ... (skip 합니다)
# 잘못된 착수일자 :  4 ... (skip 합니다)
# 잘못된 착수일자 :  25 ... (skip 합니다)
# 잘못된 착수일자 :  25 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  66 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  36 ... (skip 합니다)
# 잘못된 착수일자 :  160 ... (skip 합니다)
# 잘못된 착수일자 :  100 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  75 ... (skip 합니다)
# 잘못된 착수일자 :  78 ... (skip 합니다)
# 잘못된 착수일자 :  20 ... (skip 합니다)
# 잘못된 착수일자 :  23 ... (skip 합니다)
# 잘못된 착수일자 :  30 ... (skip 합니다)
# 잘못된 착수일자 :  30 ... (skip 합니다)
# 잘못된 착수일자 :  18 ... (skip 합니다)
# 잘못된 착수일자 :  19 ... (skip 합니다)
# 잘못된 착수일자 :  63 ... (skip 합니다)
# 잘못된 착수일자 :  55 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  23 ... (skip 합니다)
# 잘못된 착수일자 :  20 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  66 ... (skip 합니다)
# 잘못된 착수일자 :  63 ... (skip 합니다)
# 잘못된 착수일자 :  20 ... (skip 합니다)
# 잘못된 착수일자 :  20 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  79 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  43 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  5 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  23 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  145 ... (skip 합니다)
# 잘못된 착수일자 :  147 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  15 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  15 ... (skip 합니다)
# 잘못된 착수일자 :  15 ... (skip 합니다)
# 잘못된 착수일자 :  43 ... (skip 합니다)
# 잘못된 착수일자 :  43 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  101 ... (skip 합니다)
# 잘못된 착수일자 :  110 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  18 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  109 ... (skip 합니다)
# 잘못된 착수일자 :  32 ... (skip 합니다)
# 잘못된 착수일자 :  21 ... (skip 합니다)
# 잘못된 착수일자 :  77 ... (skip 합니다)
# 잘못된 착수일자 :  130 ... (skip 합니다)
# 잘못된 착수일자 :  132 ... (skip 합니다)
# 잘못된 착수일자 :  19 ... (skip 합니다)
# 잘못된 착수일자 :  19 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  15 ... (skip 합니다)
# 잘못된 착수일자 :  35 ... (skip 합니다)
# 잘못된 착수일자 :  35 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  107 ... (skip 합니다)
# 잘못된 착수일자 :  115 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  10 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  20 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  164 ... (skip 합니다)
# 잘못된 착수일자 :  55 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  95 ... (skip 합니다)
# 잘못된 착수일자 :  75 ... (skip 합니다)
# 잘못된 착수일자 :  67 ... (skip 합니다)
# 잘못된 착수일자 :  56 ... (skip 합니다)
# 잘못된 착수일자 :  48 ... (skip 합니다)
# 잘못된 착수일자 :  21 ... (skip 합니다)
# 잘못된 착수일자 :  21 ... (skip 합니다)
# 잘못된 착수일자 :  91 ... (skip 합니다)
# 잘못된 착수일자 :  40 ... (skip 합니다)
# 잘못된 착수일자 :  31 ... (skip 합니다)
# 잘못된 착수일자 :  32 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  13 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  43 ... (skip 합니다)
# 잘못된 착수일자 :  43 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  14 ... (skip 합니다)
# 잘못된 착수일자 :  20 ... (skip 합니다)
# 잘못된 착수일자 :  20 ... (skip 합니다)
# 잘못된 착수일자 :  75 ... (skip 합니다)
# 잘못된 착수일자 :  20 ... (skip 합니다)
# 잘못된 착수일자 :  20 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  39 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  17 ... (skip 합니다)
# 잘못된 착수일자 :  44 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  65 ... (skip 합니다)
# 잘못된 착수일자 :  65 ... (skip 합니다)
# 잘못된 착수일자 :  24 ... (skip 합니다)
# 잘못된 착수일자 :  24 ... (skip 합니다)
# 잘못된 착수일자 :  32 ... (skip 합니다)
# 잘못된 착수일자 :  32 ... (skip 합니다)
# 잘못된 착수일자 :  28 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  15 ... (skip 합니다)
# 잘못된 착수일자 :  19 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  55 ... (skip 합니다)
# 잘못된 착수일자 :  55 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  123 ... (skip 합니다)
# 잘못된 착수일자 :  113 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  21 ... (skip 합니다)
# 잘못된 착수일자 :  21 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  46 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  11 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  66 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  24 ... (skip 합니다)
# 잘못된 착수일자 :  3 ... (skip 합니다)
# 잘못된 착수일자 :  3 ... (skip 합니다)
# 잘못된 착수일자 :  3 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  83 ... (skip 합니다)
# 잘못된 착수일자 :  78 ... (skip 합니다)
# 잘못된 착수일자 :  53 ... (skip 합니다)
# 잘못된 착수일자 :  52 ... (skip 합니다)
# 잘못된 착수일자 :  32 ... (skip 합니다)
# 잘못된 착수일자 :  32 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  2 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  231 ... (skip 합니다)
# 잘못된 착수일자 :  231 ... (skip 합니다)
# 잘못된 착수일자 :  95 ... (skip 합니다)
# 잘못된 착수일자 :  95 ... (skip 합니다)
# 잘못된 착수일자 :  45 ... (skip 합니다)
# 잘못된 착수일자 :  45 ... (skip 합니다)
# 잘못된 착수일자 :  31 ... (skip 합니다)
# 잘못된 착수일자 :  31 ... (skip 합니다)
# 잘못된 착수일자 :  24 ... (skip 합니다)
# 잘못된 착수일자 :  24 ... (skip 합니다)
# 잘못된 착수일자 :  194 ... (skip 합니다)
# 잘못된 착수일자 :  190 ... (skip 합니다)
# 잘못된 착수일자 :  90 ... (skip 합니다)
# 잘못된 착수일자 :  86 ... (skip 합니다)
# 잘못된 착수일자 :  42 ... (skip 합니다)
# 잘못된 착수일자 :  42 ... (skip 합니다)
# 잘못된 착수일자 :  21 ... (skip 합니다)
# 잘못된 착수일자 :  21 ... (skip 합니다)
# 잘못된 착수일자 :  195 ... (skip 합니다)
# 잘못된 착수일자 :  195 ... (skip 합니다)
# 잘못된 착수일자 :  93 ... (skip 합니다)
# 잘못된 착수일자 :  93 ... (skip 합니다)
# 잘못된 착수일자 :  44 ... (skip 합니다)
# 잘못된 착수일자 :  44 ... (skip 합니다)
# 잘못된 착수일자 :  24 ... (skip 합니다)
# 잘못된 착수일자 :  24 ... (skip 합니다)
# 잘못된 착수일자 :  185 ... (skip 합니다)
# 잘못된 착수일자 :  184 ... (skip 합니다)
# 잘못된 착수일자 :  84 ... (skip 합니다)
# 잘못된 착수일자 :  83 ... (skip 합니다)
# 잘못된 착수일자 :  42 ... (skip 합니다)
# 잘못된 착수일자 :  42 ... (skip 합니다)
# 잘못된 착수일자 :  22 ... (skip 합니다)
# 잘못된 착수일자 :  22 ... (skip 합니다)
# 잘못된 착수일자 :  72 ... (skip 합니다)
# 잘못된 착수일자 :  88 ... (skip 합니다)
# 잘못된 착수일자 :  122 ... (skip 합니다)
# 잘못된 착수일자 :  113 ... (skip 합니다)
# 잘못된 착수일자 :  79 ... (skip 합니다)
# 잘못된 착수일자 :  72 ... (skip 합니다)
# 잘못된 착수일자 :  155 ... (skip 합니다)
# 잘못된 착수일자 :  99 ... (skip 합니다)
# 잘못된 착수일자 :  63 ... (skip 합니다)
# 잘못된 착수일자 :  75 ... (skip 합니다)
# 잘못된 착수일자 :  124 ... (skip 합니다)
# 잘못된 착수일자 :  114 ... (skip 합니다)
# 잘못된 착수일자 :  80 ... (skip 합니다)
# 잘못된 착수일자 :  72 ... (skip 합니다)
# 잘못된 착수일자 :  98 ... (skip 합니다)
# 잘못된 착수일자 :  81 ... (skip 합니다)
# 잘못된 착수일자 :  65 ... (skip 합니다)
# 잘못된 착수일자 :  51 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  9 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  41 ... (skip 합니다)
# 잘못된 착수일자 :  41 ... (skip 합니다)
# 잘못된 착수일자 :  27 ... (skip 합니다)
# 잘못된 착수일자 :  27 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  7 ... (skip 합니다)
# 잘못된 착수일자 :  6 ... (skip 합니다)
# 잘못된 착수일자 :  39 ... (skip 합니다)
# 잘못된 착수일자 :  38 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  16 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  0 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  1 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 잘못된 착수일자 :  8 ... (skip 합니다)
# 처리된 행 수(working day = 0 포함) :  0
# 전체 행 수 :  21629

# %%
print(dfDailyHistory) # 최종 데이터 테이블을 출력
# Out:
#             date  1.가공>중량  1.가공>절단장
# 0     2016-01-01        0         0
# 1     2016-01-04        0         0
# 2     2016-01-05        0         0
# 3     2016-01-06        0         0
# 4     2016-01-07        0         0
# ...          ...      ...       ...
# 2081  2023-12-25        0         0
# 2082  2023-12-26        0         0
# 2083  2023-12-27        0         0
# 2084  2023-12-28        0         0
# 2085  2023-12-29        0         0
#
# [2086 rows x 3 columns]

# %%
# 처리 과정에서 문제가 발생한 행 수를 출력
errorCount = len(dfExcel) - processedRows
print("오류 발생 행 수: ", errorCount)
print("오류 행의 비율: ", errorCount / len(dfExcel))
# Out:
# 오류 발생 행 수:  21629
# 오류 행의 비율:  1.0

# %% [markdown]
# 파일에 저장하기

# %%
if True:
    print("save to : ", dst_dir + dst_filename)
    dfDailyHistory.to_excel(dst_dir + dst_filename)
# Out:
# save to :  ../4.1 일단위로 작업량 계산된 엑셀 파일/3_조립실적_전체_2023.xlsx

# %% [markdown]
# 그래프로 시각화하기

# %%
# 한글 폰트 인식
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
dfDailyHistory.plot()
# Out:
# <Axes: >
# C:\Users\slsl9\AppData\Roaming\Python\Python311\site-packages\IPython\core\events.py:93: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\slsl9\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# THE END
